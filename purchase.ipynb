# %%
# !pip install pandas
# !pip install scikit-learn
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.13/site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.13/site-packages (1.7.1)
# Requirement already satisfied: numpy>=1.22.0 in ./.venv/lib/python3.13/site-packages (from scikit-learn) (2.3.2)
# Requirement already satisfied: scipy>=1.8.0 in ./.venv/lib/python3.13/site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.13/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.13/site-packages (from scikit-learn) (3.6.0)

# %%
import pandas as pd
from scipy.stats import zscore

# %% [markdown]
# ## Read in data

# %%
df = pd.read_csv("customer_purchase_sample.csv")

# %% [markdown]
# ## Fill in missing values

# %% [markdown]
# ### Check for missing values

# %%
df_na = df[df.isna().any(axis=1)]
df_na
# Out:
#      age     income   location   device referral_source      campaign  \
# 10    48        NaN      South  desktop          search   spring_sale
# 35    21        NaN       West   mobile          search          none
# 42    57   57912.18      South   mobile          search  new_arrivals
# 51    29        NaN  Northeast   mobile          search   spring_sale
# 55    20   81440.85        NaN  desktop          search          none
# 69    44        NaN    Midwest  desktop          search   spring_sale
# 89    65        NaN      South  desktop          direct          none
# 99    25   90297.20        NaN   mobile          search          none
# 102   63   91846.85      South   mobile          search  loyalty_push
# 104   63        NaN      South  desktop          search   spring_sale
# 108   44   67278.79  Northeast  desktop          search          none
# 110   33  121175.61        NaN  desktop          search  loyalty_push
# 123   44   52096.43        NaN   mobile          search          none
# 126   22        NaN    Midwest  desktop          social          none
# 144   74   95552.69      South   mobile          search          none
# 146   19   85002.53        NaN   mobile          search   spring_sale
# 152   70   96575.40        NaN  desktop          direct          none
# 154   42        NaN      South   mobile          search          none
# 206   61   69451.60    Midwest  desktop          social          none
# 224   59        NaN       West   mobile          social          none
# 229   28   67871.69        NaN   tablet          direct          none
# 242   23        NaN  Northeast   mobile          social          none
# 243   55   62692.35        NaN   mobile          search          none
#
#      pages_viewed  time_on_site_sec  is_returning_user  prior_purchases  \
# 10             10            7200.0                  1                0
# 35              3             256.0                  1                0
# 42              9               NaN                  1                2
# 51              8              83.0                  1                1
# 55              3             107.0                  1                0
# 69             12              83.0                  1                0
# 89              8              96.0                  0                1
# 99              7             164.0                  1                1
# 102             7               NaN                  0                0
# 104            10               NaN                  1                1
# 108             2               NaN                  0                0
# 110             7             296.0                  1                0
# 123             7             201.0                  1                0
# 126             9             376.0                  0                0
# 144             8               NaN                  0                1
# 146            12             175.0                  0                0
# 152             8             273.0                  0                0
# 154             8             209.0                  1                1
# 206            12               NaN                  1                0
# 224             7              10.0                  1                1
# 229             5              40.0                  0                1
# 242            10             253.0                  1                0
# 243             6              92.0                  1                1
#
#      days_since_last_visit  emails_opened_30d  ad_clicks_30d  purchased
# 10                       3                  0              0          1
# 35                      22                  2              2          0
# 42                       3                  0              2          1
# 51                       4                  0              0          0
# 55                       4                  1              1          0
# 69                      53                  2              1          0
# 89                       2                  3              0          0
# 99                      18                  1              1          1
# 102                      4                  1              1          1
# 104                     11                  0              1          0
# 108                     13                  0              0          1
# 110                     13                  4              0          1
# 123                      7                  2              0          0
# 126                      0                  3              0          1
# 144                      4                  0              0          0
# 146                     19                  1              0          0
# 152                      1                  1              1          0
# 154                     10                  1              1          0
# 206                      0                  1              2          1
# 224                     47                  2              2          0
# 229                     36                  0              1          0
# 242                      4                  1              1          0
# 243                      0                  2              3          0

# %%
df.head(12)
# Out:
#     age     income   location   device referral_source      campaign  \
# 0    23  125775.63  Northeast   mobile           email  new_arrivals
# 1    62  110053.34  Northeast  desktop          direct          none
# 2    55   95706.13       West   mobile          social          none
# 3    43  128899.09    Midwest   tablet          social          none
# 4    42   49337.11  Northeast   mobile          direct          none
# 5    66   65807.45  Northeast   mobile          search          none
# 6    22   57202.72    Midwest  desktop          search   spring_sale
# 7    57   73305.71      South   mobile          search   spring_sale
# 8    29   43699.42       West   mobile           email          none
# 9    23  104054.53      South   mobile          direct   spring_sale
# 10   48        NaN      South  desktop          search   spring_sale
# 11   73   40875.81       West  desktop           email          none
#
#     pages_viewed  time_on_site_sec  is_returning_user  prior_purchases  \
# 0              8             115.0                  1                2
# 1              9             249.0                  1                1
# 2              9             154.0                  0                1
# 3              4             133.0                  1                2
# 4              6             306.0                  0                0
# 5              6              85.0                  1                0
# 6              8             108.0                  0                0
# 7              8             199.0                  0                0
# 8              6             215.0                  1                0
# 9              5             224.0                  1                0
# 10            10            7200.0                  1                0
# 11             7             197.0                  0                0
#
#     days_since_last_visit  emails_opened_30d  ad_clicks_30d  purchased
# 0                      47                  0              0          0
# 1                       4                  6              1          1
# 2                      12                  0              1          1
# 3                       1                  0              0          0
# 4                       5                  0              0          0
# 5                      14                  0              0          0
# 6                      45                  1              1          0
# 7                      49                  2              1          0
# 8                       0                  1              0          1
# 9                      14                  0              0          0
# 10                      3                  0              0          1
# 11                     31                  1              1          0

# %% [markdown]
# Get the mode (most common) location

# %%
location_mode = df["location"].mode()[0]
location_mode
# Out:
# 'Northeast'

# %% [markdown]
# Fill missing values with mean or mode

# %%
df["income"] = df["income"].fillna(df["income"].mean())
df["time_on_site_sec"] = df["time_on_site_sec"].fillna(df["time_on_site_sec"].mean())
df["location"] = df["location"].fillna(location_mode)

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [age, income, location, device, referral_source, campaign, pages_viewed, time_on_site_sec, is_returning_user, prior_purchases, days_since_last_visit, emails_opened_30d, ad_clicks_30d, purchased]
# Index: []

# %% [markdown]
# ## Scale numeric variables

# %%
df['income'] = zscore(df['income'])
df['pages_viewed'] = zscore(df['pages_viewed'])
df['time_on_site_sec'] = zscore(df['time_on_site_sec'])
df['prior_purchases'] = zscore(df['prior_purchases'])
df['days_since_last_visit'] = zscore(df['days_since_last_visit'])
df['emails_opened_30d'] = zscore(df['emails_opened_30d'])
df['ad_clicks_30d'] = zscore(df['ad_clicks_30d'])

# %%
df.head(12)
# Out:
#     age        income   location   device referral_source      campaign  \
# 0    23  1.254536e+00  Northeast   mobile           email  new_arrivals
# 1    62  7.535704e-01  Northeast  desktop          direct          none
# 2    55  2.964196e-01       West   mobile          social          none
# 3    43  1.354060e+00    Midwest   tablet          social          none
# 4    42 -1.181055e+00  Northeast   mobile          direct          none
# 5    66 -6.562538e-01  Northeast   mobile          search          none
# 6    22 -9.304296e-01    Midwest  desktop          search   spring_sale
# 7    57 -4.173338e-01      South   mobile          search   spring_sale
# 8    29 -1.360691e+00       West   mobile           email          none
# 9    23  5.624280e-01      South   mobile          direct   spring_sale
# 10   48 -9.273468e-16      South  desktop          search   spring_sale
# 11   73 -1.450660e+00       West  desktop           email          none
#
#     pages_viewed  time_on_site_sec  is_returning_user  prior_purchases  \
# 0       0.077357         -0.222350                  1         1.685035
# 1       0.245524          0.074710                  1         0.427546
# 2       0.245524         -0.135892                  0         0.427546
# 3      -0.595312         -0.182446                  1         1.685035
# 4      -0.258978          0.201071                  0        -0.829943
# 5      -0.258978         -0.288855                  1        -0.829943
# 6       0.077357         -0.237868                  0        -0.829943
# 7       0.077357         -0.036133                  0        -0.829943
# 8      -0.258978         -0.000663                  1        -0.829943
# 9      -0.427145          0.019289                  1        -0.829943
# 10      0.413691         15.484123                  1        -0.829943
# 11     -0.090810         -0.040567                  0        -0.829943
#
#     days_since_last_visit  emails_opened_30d  ad_clicks_30d  purchased
# 0                2.240592          -1.025078      -0.865744          0
# 1               -0.724248           4.066371       0.285511          1
# 2               -0.172650          -1.025078       0.285511          1
# 3               -0.931098          -1.025078      -0.865744          0
# 4               -0.655299          -1.025078      -0.865744          0
# 5               -0.034751          -1.025078      -0.865744          0
# 6                2.102693          -0.176504       0.285511          0
# 7                2.378492           0.672071       0.285511          0
# 8               -1.000048          -0.176504      -0.865744          1
# 9               -0.034751          -1.025078      -0.865744          0
# 10              -0.793198          -1.025078      -0.865744          1
# 11               1.137396          -0.176504       0.285511          0

# %% [markdown]
# ## One-hot encode categorical data

# %%
def one_hot(df, cols):
    """
    @param df pandas DataFrame
    @param cols a list of columns to encode 
    @return a DataFrame with one-hot encoding
    """
    for each in cols:
        dummies = pd.get_dummies(df[each], prefix=each, drop_first=False)
        df = pd.concat([df, dummies], axis=1)
    return df

# %%
one_hot(df, ["location", "device", "referral_source", "campaign"])
# Out:
#      age    income   location   device referral_source      campaign  \
# 0     23  1.254536  Northeast   mobile           email  new_arrivals
# 1     62  0.753570  Northeast  desktop          direct          none
# 2     55  0.296420       West   mobile          social          none
# 3     43  1.354060    Midwest   tablet          social          none
# 4     42 -1.181055  Northeast   mobile          direct          none
# ..   ...       ...        ...      ...             ...           ...
# 245   22  0.148671      South  desktop          search   spring_sale
# 246   61  0.762435       West   mobile          search          none
# 247   41 -0.033792       West   tablet          search          none
# 248   62  1.225642  Northeast  desktop          social          none
# 249   20  0.774297    Midwest  desktop          search          none
#
#      pages_viewed  time_on_site_sec  is_returning_user  prior_purchases  ...  \
# 0        0.077357         -0.222350                  1         1.685035  ...
# 1        0.245524          0.074710                  1         0.427546  ...
# 2        0.245524         -0.135892                  0         0.427546  ...
# 3       -0.595312         -0.182446                  1         1.685035  ...
# 4       -0.258978          0.201071                  0        -0.829943  ...
# ..            ...               ...                ...              ...  ...
# 245     -0.763479         -0.217916                  1        -0.829943  ...
# 246     -0.258978          0.221023                  0        -0.829943  ...
# 247     -0.931647          0.070276                  0        -0.829943  ...
# 248      0.750026          0.050325                  1        -0.829943  ...
# 249      0.077357          0.043674                  1         0.427546  ...
#
#      device_tablet  referral_source_ads  referral_source_direct  \
# 0            False                False                   False
# 1            False                False                    True
# 2            False                False                   False
# 3             True                False                   False
# 4            False                False                    True
# ..             ...                  ...                     ...
# 245          False                False                   False
# 246          False                False                   False
# 247           True                False                   False
# 248          False                False                   False
# 249          False                False                   False
#
#      referral_source_email  referral_source_search  referral_source_social  \
# 0                     True                   False                   False
# 1                    False                   False                   False
# 2                    False                   False                    True
# 3                    False                   False                    True
# 4                    False                   False                   False
# ..                     ...                     ...                     ...
# 245                  False                    True                   False
# 246                  False                    True                   False
# 247                  False                    True                   False
# 248                  False                   False                    True
# 249                  False                    True                   False
#
#      campaign_loyalty_push  campaign_new_arrivals  campaign_none  \
# 0                    False                   True          False
# 1                    False                  False           True
# 2                    False                  False           True
# 3                    False                  False           True
# 4                    False                  False           True
# ..                     ...                    ...            ...
# 245                  False                  False          False
# 246                  False                  False           True
# 247                  False                  False           True
# 248                  False                  False           True
# 249                  False                  False           True
#
#      campaign_spring_sale
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ..                    ...
# 245                  True
# 246                 False
# 247                 False
# 248                 False
# 249                 False
#
# [250 rows x 30 columns]
